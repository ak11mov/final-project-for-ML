# %%
import requests

url = "http://127.0.0.1:8000/predict"

data = {
  "person_age": 25,
  "person_income": 25000,
  "person_home_ownership": "RENT",
  "person_emp_length": 3,
  "loan_intent": "PERSONAL",
  "loan_grade": "C",
  "loan_amnt": 3000,
  "loan_int_rate": 12.5,
  "loan_percent_income": 0.1,
  "cb_person_default_on_file": "N",
  "cb_person_cred_hist_length": 5
}

response = requests.post(url, json=data)
print(response.json())
# Out:
# {'prediction': 0, 'probability_default': 0.21499384327503449, 'risk_level': 'Средний'}
